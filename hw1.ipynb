# %% [markdown]
# # Домашнее задание 1 (29 + 25 + 27 + 30 = 111 pts)
# ## Выполнил Куркин Максим Леонидович

# %% [markdown]
# ## Задача 1 (29 pts)

# %% [markdown]
# - (3 pts) Докажите, что $\| A \|_F \le \sqrt{\mathrm{rank}(A)} \| A \|_2$.
# **Решение:** Воспользуемся свойствами норм: так как они унитарно инвариантны, спектральная норма матрицы равна максимальному сингулярному числу этой матрицы, т. е. $\| A \|_2 = \sigma_{max}$, а Фробениусова - корню из суммы квадратов всех сингулярных чисел $\Rightarrow \| A \|_F = \sqrt{\mathrm{trace}(A^* A)} =  \sqrt{\sigma_1^2 + \sigma_2^2 + ... + \sigma_r^2} \leq \sqrt{r\sigma_{max}^2 } = \sqrt{\mathrm{rank}(A)}\sigma_{max}$, так как $r$ - число ненулевых сингулярных чисел матрицы $A$, $r = rank(A)$. Получим утверждение, которое требовалось доказать.

# %% [markdown]
# - (3 pts) Покажите, что для любых $m, n$ и $k \le \min(m, n)$ существует $A \in \mathbb{R}^{m \times n}: \mathrm{rank}(A) = k$, такая что $\| A \|_F = \sqrt{\mathrm{rank}(A)} \| A \|_2$.
# **Решение:** Требуется доказать, что при данных условия существует вещественная матрица $A$ такая, что  $\sigma_1=\sigma_2=...=\sigma_k, \, \sigma_{k+1}=...=\sigma_{min(m, n)}=0$.
# Это, например, усечённая единичная матрица $A_{ij} = \begin{cases} 1, & i = j, i \leq k\\ 0, & \text{иначе} \end{cases}$.
# $A^* A = A$, у $A$ ровно $k$ собственных значений равны 1 и $\min(m, n) - k$ собственных значений равны 0.

# %% [markdown]
# - (3 pts) Докажите, что если $\mathrm{rank}(A) = 1$, то $\| A \|_F  = \| A \|_2$.
# **Решение**: Если $r = \mathrm{rank}(A) = 1$, то у $A$ только одно ненулевое сингулярное число $\sigma_{max} > 0$, $\| A \|_F  = \sigma_{max} = \sqrt{\mathrm{rank}(A)} \| A \|_2$.

# %% [markdown]
# - (3 pts) Докажите, что $\| A B \|_F \le \| A \|_2 \| B \|_F$.
# **Решение:** Пусть $A = (a_1, a_2, ..., a_n)$  (строки), $B = (b_1, b_2, ... b_m)$  (столбцы).
# Тогда требуется доказать, что  $$\|A B\|_{F}^{2}=\sum_{i, j} (a_i, b_j)^2 = \sum_{j=1}^{m} \|Ab_j\|_2^2 \leq \sup_{\|x\|=1}{\|Ax\|^2_2} \sum_{j} (b_{j}^\top, b_{j})^2 = \sup_{\|x\|=1}{\|Ax\|^2_2} \sum_{j=1}^{m} \|b_j\|_2^2$$
# Очевидно неравенство для спектральной нормы: $\| Ax \|_2^2 \leq \|A\|_2^2 \|x\|_2^2$, значит, $$\sum_{j=1}^{m} \|Ab_j\|_2^2 \leq \|A\|_2^2 \sum_{i=1}^{m}\|b_j\|_2^2  = \sup_{\|x\|=1}{\|Ax\|^2_2} \sum_{j=1}^{m} \|b_j\|_2^2 .$$   Утверждение доказано.

# %% [markdown]
# - (5 pts) Для векторов важным дополнительным свойством является количество ненулевых элементов. В задаче решения недоопределённой системы линейных уравнений это свойство является одним из возможных дополнительных условий на решение. Аналогичная задача для матриц – это поиск наилучшего приближения данной матрицы с минимальным рангом. То есть аналогом разреженности для векторов является малоранговость для матриц. Возникает вопрос, какая норма является аналогичной первой векторной нормы? Ответом является так называемая ядерная норма
#
# $$\|A\|_{nuclear} = \sum_{i=1}^n \sigma_i, $$
#
# где $\sigma_i$ – сингулярные числа матрицы $A$. Покажите, что это выражение действительно является нормой.
# **Решение:** Проверим аксиомы нормы.
# Аксиома неотрицательности, очевидно, выполнена: $$\sigma_i \geq 0 \Rightarrow \sum_{i=1}^n \sigma_i \geq 0, \; \sum_{i=1}^n \sigma_i = 0 \Leftrightarrow A = O. $$
# Аксиома однородности тоже выполнена в силу сингулярной инвариантности нормы: $$\| \alpha A \|= \| \alpha U\Sigma V^* \|= \|U\| \| \alpha \Sigma \| \|V^*\| = \| \alpha \Sigma \| = |\alpha| \| \Sigma\| = |\alpha| \|A\|.$$
# Аксиому треугольника можно доказать, переписав эту норму в следующем виде: $$\|A\|_{nuclear} = \sum_{i=1}^n \sigma_i  = \sup_{U \; - \; унитарна}{|\text{trace}(AU)|}. $$ Это выполнено в силу определения сингулярного разложения.
# В силу свойства следа - $\text{trace}(XY) = \text{trace}(YX)$ верно $$\sup_{U \; - \; унитарна}{|\text{trace}(AU)|} = \sup_{U \; - \; унитарна}{|\text{trace}(\Sigma U)|} \;(\leq \; \text{при} \; U = I, \; \geq \; \text{так как} \; |\text{trace}\Sigma U| \leq \text{trace}(\Sigma)).$$
# Поэтому $$\sum_{i=1}^n \sigma_i(A+B) = \sup_{U \; - \; унитарна}{|\text{trace}((A+B)U)|} \leq \sup_{U \; - \; унитарна}{|\text{trace}(AU)| + |\text{trace}(BU)|} \leq \sup_{U \; - \; унитарна}{|\text{trace}(AU)|} + \sup_{U \; - \; унитарна}{|\text{trace}(BU)|}.$$

# %% [markdown]
# - (2 pts) Докажите, что для любой эрмитовой матрицы сингулярные числа совпадают с абсолютными значениями собственных значений. Выполнено ли это для произвольной матрицы? Докажите, что выполнено или приведите контрпример.
# **Решение**: $A = A^* \Rightarrow A^* A = A^2$. Матрицу $А$ можно диагонализовать унитарной матрицей $P$: $A = PDP^{-1}$.
# Значит, $A^*A$ тоже диагонализуема $P$: $A^{*} A=A^{2}=P D P^{-1} P D P^{-1}=P D^{2} P^{-1}$. На диагонали матрицы $D^2$ лежат $\lambda_i^2$, где $\lambda_i$ - собственные значения матрицы $A$, поэтому $|\lambda_i| = \sigma_i$.
# Так диагонализовать можно не любую матрицу, например, у  $\begin{pmatrix} 0 & 1 \\ 0 & 0 \end{pmatrix}$   $\quad \lambda_{1, 2} = 0$, но $\sigma_1 = 1, \, \sigma_2 = 0$.

# %% [markdown]
# - (3 pts) Найдите скелетное разложение матрицы $\begin{pmatrix} 1 & -2 & 5 \\ 5 & 3 & 9 \\ 3 & 7 & -1\end{pmatrix}$.
# **Решение:** Первая строка матрицы есть полуразность второй и третьей, поэтому в качестве строк $V$ в разложении $A = UV$ удобно взять вторую и третью строки $A$.
# $\begin{pmatrix} 1 & -2 & 5 \\ 5 & 3 & 9 \\ 3 & 7 & -1\end{pmatrix} = \begin{pmatrix} 0.5 & -0.5 \\ 1 & 0 \\ 0 & 1 \end{pmatrix} \begin{pmatrix} 5 & 3 & 9 \\ 3 & 7 & -1\end{pmatrix}$

# %% [markdown]
# - (1 pts) Покажите, что если матрица $A$ обратима, то $\|A^{-1}\|_F \geq \frac{\sqrt{n}}{\|A\|_F}$
# **Решение:** Так как сингулярные числа обратной матрицы равны $\frac{1}{\sigma_n}, ... \frac{1}{\sigma_1}$, то $\|A^{-1}\|^2_F = \frac{1}{\sigma^2_n} + ... + \frac{1}{\sigma^2_1} $ и
# $\|A^{-1}\|^2_F \|A \|^2_F  = n + \sum_{i \ne j} \sum_{i=1}^{n} \frac{\sigma_i}{\sigma_j}  \ge n$, что и требовалось доказать.

# %% [markdown]
# - (3 pts) Рассмотрим матрицу $A = \begin{bmatrix} I & a \\ a^{\top} & 0 \end{bmatrix}$. Когда она является обратимой? Пусть она обратима, тогда найдите выражение для $A^{-1}$
# **Решение:**
#     Пусть $X = \begin{pmatrix} A & B \\ C & D \end{pmatrix}$ - матрица из 4 блоков. Тогда если $|A| \ne 0$, то $|X|=|A| \cdot\left|D-C A^{-1} B\right|$.
#     Доказательство:
#     $\begin{pmatrix} A & B \\ C & D \end{pmatrix} \begin{pmatrix} I & -A^{-1}B \\ 0 & I \end{pmatrix} = \begin{pmatrix} A & 0 \\ C & D-CA^{-1}B \end{pmatrix}$; $\quad |XY| = |X||Y|$, здесь $|Y| = 1$.
#     $A$ обратима $\Leftrightarrow |A| \ne 0  \Leftrightarrow |I| \cdot \left | 0 - a^{\top} I a \right | = 1 \cdot |(a, a)| \Rightarrow$ критерий обратимости $A$ - $(a, a) \ne 0 \Leftrightarrow a \ne 0$.
#     Формула Фробениуса обращения невырожденной блочной матрицы(проверить её можно непосредственно перемножив исходную и обратную матрицы):
# $$\left(\begin{array}{cc}A & B \\ C & D\end{array}\right)^{-1}=\left(\begin{array}{cc}A^{-1}+A^{-1} B H^{-1} C A^{-1} & -A^{-1} B H^{-1} \\ -H^{-1} C A^{-1} & H^{-1}\end{array}\right), \; H=D-C A^{-1} B
# $$
#     Пользуясь этим, получим $$H = -a^\top I a = -(a, a)I, \; A^{-1} = {\begin{pmatrix} I & a \\ a^\top & 0 \end{pmatrix}}^{-1} = \begin{pmatrix} (1-(a, a)^2)I &  \frac{a}{(a, a)}\\ \frac{a^\top}{(a, a)} & -\frac{1}{(a, a)}I \end{pmatrix}$$

# %% [markdown]
# - (3 pts) Пусть матрица $A$ ортогональна и все её элементы неотрицательны, то есть $a_{ij} \geq 0$. Покажите, что тогда $A$ есть матрица перестановки
# **Решение:** Пусть в каких-то столбцах есть более одного положительного элемента. Тогда по принципу Дирихле найдётся строка, которая положительна хотя бы в двух позициях, что противоречит ортогональности - строки больше не образуют базис т. е. $\sum_{i} A_{i j} A_{i k} \ne\delta_{j k} $. Значит, в каждой строке и каждом столбце только один положительный элемент, равный $1$.

# %% [markdown]
# ## Задача 2. LU разложение (25 pts)

# %% [markdown]
# ### 1. LU разложение для ленточных матриц
#
# Сложность вычисления LU разложения для матрицы размера $n\times n$ – $\mathcal{O}(n^3)$.
# Существенного уменьшения сложности можно добиться для матриц определённой структуры, например разреженных.
# В этой задаче рассмотрим специальный класс разреженных матриц, а именно ленточные матрицы с шириной ленты 3 и 5, которые называются трёхдиагональными и пятидиагональными, соответственно.
#
# - (5 pts) Реализуйте функцию ```band_lu(diag_broadcast, n)```, которая вычисляет LU разложение для пяти- или трёхдиагональной матрицы, на основании данных значений на диагоналях. Предполагается, что на главной диагонали фактора ```L``` стоят 1.
# Например, входные параметры ```(diag_broadcast = [3,-5,4], n = 4)``` означают, что необходимо найти LU разложение для трёхдиагональной матрицы вида:
#
# $$A = \begin{pmatrix}
# -5 & 4 & 0 & 0\\
# 3 & -5 & 4 & 0 \\
# 0 & 3 & -5 & 4 \\
# 0 & 0 & 3 & -5 \\
# \end{pmatrix}.$$
#
# Функция должна возвращать двумерные NumPy массивы ```L``` и ```U```, в которых хранятся диагонали факторов. Например, ```L[0]``` содержит первую под-диагональ (поскольку на главной диагонали стоят 1, то её возвращать не нужно), ```L[1]``` – вторую под-диагональ и т.д.), аналогично для $U$ (```U[:,0]``` содержит главную диагональ, ```U[:,1]``` содержит первую над-диагональ и т.д.). Прототип функции приведён ниже и не должен меняться.
# - (2 pts) Сравните время вычисления LU разложения с помощью стандартной функции в ```scipy```, которая ничего не знает о структуре матрицы, и вашей реализацией LU разложения для ленточной матрицы. Объясните результат. Постройте график зависимости времени факторизации от размерности факторизуемой матрицы. Выберите интервал размерностей факторизуемой матрицы так, чтобы динамика зависимости времени от размерности была различима. При необходимости используйте логарифмический масштаб по оси ```y```.

# %%
import scipy
import numpy as np
import pandas as pd

# %%
# INPUT : diag_broadcast - list of diagonals value to broadcast, length equal to 3 or 5; n - integer, band matrix shape.
# OUTPUT : L - 2D np.ndarray, L.shape[0] depends on bandwidth, L.shape[1] = n-1, do not store main diagonal, where all ones;                  add zeros to the right side of rows to handle with changing length of diagonals.
#          U - 2D np.ndarray, U.shape[0] = n, U.shape[1] depends on bandwidth;
#              add zeros to the bottom of columns to handle with changing length of diagonals.
def band_lu(diag_broadcast, n):
    bandwidth = len(diag_broadcast) - 2
    L = np.empty((bandwidth, n-1))
    U = np.empty((n, bandwidth))
    if bandwidth == 1:
        u = l  = 0
        for i in range(n):
            u = diag_broadcast[1] - l * diag_broadcast[2]
            U = np.append(U, [[u], [diag_broadcast[2]]], axis=1)
            l = diag_broadcast[0] / u
            L = np.append(L, l)
    return L, U

# %%
l, u = band_lu([3,15,4], 4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-4db30ae08b67> in <module>
# ----> 1 l, u = band_lu([3,15,4], 4)
#
# <ipython-input-4-b788b0a88b28> in band_lu(diag_broadcast, n)
#      11         for i in range(n):
#      12             u = diag_broadcast[1] - l * diag_broadcast[2]
# ---> 13             U = np.append(U, [[u], [diag_broadcast[2]]], axis=1)
#      14             l = diag_broadcast[0] / u
#      15             L = np.append(L, l)
#
# <__array_function__ internals> in append(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in append(arr, values, axis)
#    4743         values = ravel(values)
#    4744         axis = arr.ndim-1
# -> 4745     return concatenate((arr, values), axis=axis)
#    4746
#    4747
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 4 and the array at index 1 has size 2

# %% [markdown]
# ### 2. Устойчивость LU разложения
#
# Рассмотрим матрицу вида
# $A = \begin{pmatrix}
# \varepsilon & 1 & 0\\
# 1 & 1 & 1 \\
# 0 & 1 & 1
# \end{pmatrix}.$

# %% [markdown]
# * (5 pts) Вычислите аналитически LU разложение с и без выбора ведущего элемента в строке.
# **Решение:**
# Пользуемся формулами:
# $$
# \begin{array}{l}u_{11}=a_{11}, \\ u_{i i+1}=a_{i i+1}, \quad i \in[1, n-1] \\ l_{i+1 i}=a_{i+1 i} / u_{i i}, \quad i \in[1, n-1] \\ u_{i i}=a_{i i}-l_{i i-1} u_{i-1 i}, \quad i \in[2, n]\end{array}
# $$
# Без выбора ведущего элемента: $A = \begin{pmatrix}
# \varepsilon & 1 & 0\\
# 1 & 1 & 1 \\
# 0 & 1 & 1
# \end{pmatrix} =
# \begin{pmatrix}
# 1 & 0 & 0\\
# \frac{1}{\varepsilon} & 1 & 0 \\
# 0 & \frac{\varepsilon}{\varepsilon-1} & 1
# \end{pmatrix}
# \begin{pmatrix}
# \varepsilon & 1 & 0\\
# 0 & \frac{\varepsilon-1}{\varepsilon} & 1 \\
# 0 & 0 & \frac{-1}{\varepsilon-1}
# \end{pmatrix}$
# С выбором ведущего элемента(учитывая, что $\varepsilon < 1$): $A =
# \begin{pmatrix} \varepsilon & 1 & 0\\ 1 & 1 & 1 \\0 & 1 & 1 \end{pmatrix} \xrightarrow{\text{меняем строки}(1\leftrightarrow 2)}
# \begin{pmatrix}1 & 1 & 1 \\ \varepsilon & 1 & 0 \\ 0 & 1 & 1 \end{pmatrix} \rightarrow
# \begin{pmatrix}1 & 1 & 1 \\ 0 & 1-\varepsilon & -\varepsilon \\ 0 & 1 & 1\end{pmatrix} \xrightarrow{(1\leftrightarrow 3)}
# \begin{pmatrix}1 & 1 & 1 \\ \varepsilon & 1 & 1 \\ 0 & 1-\varepsilon & -\varepsilon\end{pmatrix}
# \begin{pmatrix}1 & 1 & 1 \\ \varepsilon & 1 & 1 \\ 0 & 1-\varepsilon & -1\end{pmatrix}$
# $$
# L=\begin{pmatrix}1 & 0 & 0 \\ \varepsilon & 1 & 0 \\ 0 & 1-\varepsilon & 1\end{pmatrix},
# U=\begin{pmatrix}1 & 1 & 1 \\ 0 & 1 & 1 \\ 0 & 0 & -1\end{pmatrix},
# P=\begin{pmatrix}0 & 1 & 0 \\ 0 & 0 & 1 \\ 1 & 0 & 0\end{pmatrix}; AP = LU$$

# %% [markdown]
# * (3 pts) Объясните, почему алгоритм вычисления LU разложения плохо аппроксимирует факторы $L$ и $U$ для $|\varepsilon|\ll 1$ в машинной арифметике?
# **Решение**: в процессе вычисления без выбора ведущего элемента неизбежно деление на $\varepsilon$, из-за этого теряется устойчивость алгоритма. В матрице $L$ появляется большой коэффициент.

# %% [markdown]
# ### 3. Блочное LU разложение
#
# Пусть $A = \begin{bmatrix} A_{11} & A_{12} \\ A_{21} & A_{22} \end{bmatrix}$ – блочная матрица. Необходимо решить систему линейных уравнений вида
#
# $$
#      \begin{bmatrix} A_{11} & A_{12} \\ A_{21} & A_{22} \end{bmatrix} \begin{bmatrix} u_1 \\ u_2 \end{bmatrix} = \begin{bmatrix} f_1 \\ f_2 \end{bmatrix}.
# $$
#
# * (2 pts) Используя процедуру блочного исключения, найдите матрицу $S$ и правую часть $\hat{f_2}$ такую что $u_2$ может быть найден из системы $S u_2 = \hat{f_2}$. Матрица $S$ называется <font color='red'> дополнением по Шуру </font> блока  $A_{11}$.
# **Решение:** Система эквивалентна после блочного перемножения системе
# $$
# \begin{array}{l}A_{11} u_{1}+A_{12} u_{2}=f_{1} \\ A_{21} u_{1}+A_{22} u_{2}=f_{2}\end{array}
# $$
# Из первого уравнения $u_{1}=A_{11}^{-1}\left(f_{1}-A_{12} u_{2}\right)$, подставляя во второе уравнение, получим $A_{21} A_{11}^{-1}\left(f_{1}-A_{12} u_{2}\right)+A_{22} u_{2}=f_{2}$ или, эквивалентно, $\left(A_{22}-A_{21} A_{11}^{-1}A_{12}\right) u_{2}=f_{2}-A_{21} A_{11}^{-1} f_{1}$.
# Приходим к системе $$
# \begin{array}{l}A_{11} u_{1}+A_{12} u_{2}=f_{1}, \\ S u_2 = \left(A_{22}-A_{21} A_{11}^{-1} A_{12}\right) u_{2}=f_{2}-A_{21} A_{11}^{-1} f_{1} = \hat{f_2}.\end{array}
# $$

# %% [markdown]
# * (4 pts) Используя свойства дополнения по Шуру докажите, что
#
# $$\det(X+AB) = \det(X)\det(I+BX^{-1}A), $$
#
#
# где $X$ невырожденная квадратная матрица.
#
# Пусть $Y = \begin{pmatrix} X & A \\ -B & I \end{pmatrix}$.   Тогда  её определитель - $ \operatorname{det} Y=\operatorname{det}(X) \operatorname{det}\left(I+B X^{-1} A\right)=\operatorname{det}(I) \operatorname{det}\left(X+A I^{-1} B\right)=\operatorname{det}(X+A B).$

# %% [markdown]
# * (4 pts) Пусть матрица $F \in \mathbb{R}^{m \times n}$ и $G \in \mathbb{R}^{n \times m}$. Докажите, что
#
# $$\det(I_m - FG) = \det(I_n - GF).$$
# Пусть $Y = \begin{pmatrix} I_m & F \\G & I_n \end{pmatrix}$. Тогда  её определитель - $ \operatorname{det} Y=
# \operatorname{det}\left(I_{m}\right) \operatorname{det}\left(I_{n}-F G\right)=\operatorname{det}\left(I_{n}\right)\left(I_{m}-G F\right)
# $

# %% [markdown]
# ## Задача 3:  QR разложение (27 pts)
#
# - (5 pts) Реализуйте метод Грама-Шмидта для вычисления QR разложения. На вход подаётся прямоугольная матрица, функция возвращает матрицы ```Q``` и ```R``` из QR разложения. Прототип приведён ниже и не должен изменяться

# %%
# INPUT : rectangular matrix A
# OUTPUT: matrices Q - orthogonal and R - upper triangular such that A = QR
def gram_schmidt_qr(A):
    m, n = A.shape
    if m <= n:
        Q = np.zeros((m, m), dtype=A.dtype)
        R = np.zeros_like(A)
    else:
        Q = np.zeros_like(A)
        R = np.zeros((n, n), dtype=A.dtype)
    V = A.copy()
    for i in range(min(m, n)):
        R[i, i] = np.linalg.norm(V[:, i])
        Q[:, i] = V[:, i] / R[i, i]
        for j in range(i+1, n):
            R[i, j] = Q[:, i].conj().dot(V[:, j])
            V[:, j] = V[:, j] - R[i, j] * V[:, i]
    return Q, R

# %%
A = np.array([
    [1,2,3,7,1],
    [3,6,8,0,2],
    [4,7,8,0,3],
], dtype = "float")

# %%
A = np.array([
    [1,1,1],
    [3,3,3],
    [8,8,10]
], dtype = "float")

# %%
Q, R = gram_schmidt_qr(A)

# %%
print(R)
# Out:
# [[5.19615242e+00 1.00074047e+01 1.28941560e+01 3.07920144e+00]
#  [0.00000000e+00 4.20503260e+01 5.43398350e+01 1.33593031e+01]
#  [0.00000000e+00 0.00000000e+00 2.23067026e+03 5.48415031e+02]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 1.22278469e+06]]

# %%
A = np.array([
    [1,2,3,7],
    [3,6,8,0],
    [4,7,8,0],
    [0,0,1,0]
])

Q, R = gram_schmidt_qr(A)
print(np.allclose(Q@Q.T, np.eye(4)))
print(np.allclose(Q@R, A))
# Out:
# False
# False

# %%
A = np.array([
    [16,2,3],
    [3,6,8],
    [4,7,8],
    [90,0,1]
])

Q, R = gram_schmidt_qr(A)
print(np.allclose(Q@Q.T, np.eye(4)))
print(np.allclose(Q@R, A))
# Out:
# False
# False

# %%
A = np.array([
    [1,2,1],
    [0,6,8],
    [3,7,0],
    [9,1,1]
])

Q, R = modified_gram_schmidt_qr(A)
print(np.allclose(Q@Q.T, np.eye(4)))
print(np.allclose(Q@R, A))
# Out:
# False
# False

# %%
A = np.array([
    [1,2,3],
    [0,6,0],
    [0,0,8],
    [0,0,1]
])

Q, R = householder_qr(A)
print(np.allclose(Q@Q.T, np.eye(4)))
print(np.allclose(Q@R, A))
# Out:
# False
# False

# %%
np.allclose(Q @ R, A)
# Out:
# False

# %%
A = np.array([
    [1,2,3,7],
    [3,6,8,0],
    [4,7,8,0],
    [0,0,1,0],
    [1,4,8,9]
], dtype = "float")

# %% [markdown]
# - (5 pts) Реализуйте модифицированный метод Грама-Шмидта для вычисления QR разложения. На вход подаётся прямоугольная матрица, функция возвращает матрицы Q и R из QR разложения. Прототип приведён ниже и не должен изменяться

# %%
# INPUT : rectangular matrix A
# OUTPUT: matrices Q - orthogonal and R - upper triangular such that A = QR
def modified_gram_schmidt_qr(A): # 5 pts
    m, n = A.shape
    if m <= n:
        Q = np.zeros((m, m), dtype=A.dtype)
        R = np.zeros_like(A)
    else:
        Q = np.zeros_like(A)
        R = np.zeros((n, n), dtype=A.dtype)
    V = A.copy()
    for i in range(min(m, n)):
        R[i, i] = np.linalg.norm(V[:, i])
        Q[:, i] = V[:, i] / R[i, i]
        for j in range(i+1, n):
            R[i, j] = Q[:, i].conj().dot(V[:, j])
            V[:, j] = V[:, j] - R[i, j] * Q[:, i]
    return Q, R

# %% [markdown]
# - (7 pts) Реализуйте алгоритм вычисления QR разложения, основанный на преобразованиях Хаусхолдера. На вход подаётся прямоугольная матрица, функция возвращает матрицы Q и R из QR разложения. Прототип приведён ниже и не должен изменяться. Обратите внимание на эффективность реализации операции умножения матриц Хаусхолдера для получения матрицы ```Q```.

# %%
# INPUT : rectangular matrix A
# OUTPUT: matrices Q - orthogonal and R - upper triangular such that A=QR
def householder_qr(A): # 7 pts
    m, n = A.shape
    Q = np.eye(m, dtype=A.dtype)
    R = A.copy()
    for i in range(min(n, m)):
        y = R[i:, i].copy()
        #print(y)
        s = y[0] / np.linalg.norm(y[0])
        norm = np.linalg.norm(y)
        y[0] += s * norm
        w = y / np.linalg.norm(y)
        w = np.reshape(w, (w.shape[0], 1))
        #print(w)
        wTR = w.conj().T.dot(R[i:, i:])
        R[i:, i:] = R[i:, i:] - 2 * w.dot(wTR)
        Qw = Q[:, i:].dot(w)
        Q[:, i:] = Q[:, i:] - 2 * Qw.dot(w.conj().T) 
        #print(R)
    return Q, R

# %%
A = np.array([
    [1,2,3,7,1],
    [3,6,8,0,2],
    [4,7,8,0,3],
], dtype = "float")

# %%
Q, R = householder_qr(A)
# Out:
# [1. 3. 4.]
# [ 0.38586426 -0.48551433]
# [-0.31622777]

# %%
Q
# Out:
# array([[-1.96116135e-01, -2.48069469e-01,  9.48683298e-01],
#        [-5.88348405e-01, -7.44208408e-01, -3.16227766e-01],
#        [-7.84464541e-01,  6.20173673e-01,  2.60902411e-15]])

# %%
print(R)
# Out:
# [[-5.09901951e+00 -9.41357449e+00 -1.15708520e+01 -1.37281295e+00
#   -3.72620657e+00]
#  [-4.44089210e-16 -6.20173673e-01 -1.73648628e+00 -1.73648628e+00
#    1.24034735e-01]
#  [-8.88178420e-16  5.55111512e-17  3.16227766e-01  6.64078309e+00
#    3.16227766e-01]]

# %% [markdown]
# - (2 pts) Сгенерируйте квадратную [матрицу Вандермонда](https://en.wikipedia.org/wiki/Vandermonde_matrix) $V\in\mathbb{R}^{n\times n},\ n = 20$ для вектора $x$: ```x = np.linspace(0,1,n)``` и вычислите QR разложение этой матрицы с помощью каждого из трёх реализованных вами алгоритмов. Вычислите насколько столбцы матрицы $Q$ ортогональны, то есть величину $\|Q^{\top}Q - I\|_2$. Объясните полученный результат.

# %%
n = 20
x = np.linspace(0, 1, n)
A = np.vander(x)

Q1, R1 = gram_schmidt_qr(A)
print(np.linalg.norm(Q1.T @ Q1 - np.eye(Q1.shape[1]), 2))

Q2, R2 = modified_gram_schmidt_qr(A)
print(np.linalg.norm(Q2.T @ Q2 - np.eye(Q2.shape[1]), 2))

Q3, R3 = householder_qr(A)
print(np.linalg.norm(Q3.T @ Q3 - np.eye(Q3.shape[1]), 2))
# Out:
# 9.6273425155008
# 0.10444348319417061
# nan
# <ipython-input-40-e4e0139809a7>:10: RuntimeWarning: invalid value encountered in double_scalars
#   s = y[0] / np.linalg.norm(y[0])

# %% [markdown]
# Этот пример показывает, что при наивном подсчёте разложения векторы базиса получаются менее ортогональны. Ошибка нарастает из-за машинной точности.

# %% [markdown]
# - (3 pts) Изучите как скорость работы каждого из алгоритмов вычисления QR разложения зависит от числа строк и столбцов матрицы, для которой вычисляется QR разложение. Постройте два графика: на одном покажите зависимость времени вычисления от числа строк при фиксированном числе столбцов, а на другом, наоборот, зависимость времени вычисления от числа столбцов при неизменном числе строк. Выберите диапазоны изменения количества строк и столбцов такими, чтобы можно было увидеть асимптотическую скорость работы для больших матриц.

# %% [markdown]
# - (5 pts) Пусть дано QR разложение матрицы $A$ размера $m \times n, \; m > n$. К матрице $A$ добавили ещё одну строку после последней, то есть теперь есть матрица $\hat{A} = \begin{bmatrix} A \\ a \end{bmatrix}$ размера $(m+1) \times n$. Покажите, как найти QR разложение матрицы $\hat{A}$, используя QR разложения матрицы $A$. Сравните асимптотические сложности предложенного вами способа и метода, который не использует QR разложение матрицы $A$. Также экспериментально покажите, как время работы этих двух методов зависит от размерности по числу строк и столбцов матрицы.

# %% [markdown]
# ## Задача 4. Сжатие полносвязных слоёв в нейросети (30 pts)
#
# В этой задаче вам предлагается исследовать, как изменится точность предсказания нейросети, которая классифицирует изображения, если вместо полносвязных слоёв использовать их сжатое представление, полученное с помощью SVD. Результатом решения этой задачи должен быть график зависимости точности классификации на тестовой выборке от количества параметров нейронной сети.

# %% [markdown]
# #### Сначала скачаем данные CIFAR10

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

batch_size = 100

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=True, download=True, transform=transform), 
                                        batch_size=batch_size, shuffle=True)

test_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=False, transform=transform), 
                                          batch_size=batch_size, shuffle=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified

# %% [markdown]
# #### Посмотрим, как выглядят изображения

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(20, 10))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(8)))
# Out:
# horse truck   cat   cat   cat truck   cat  deer

# %% [markdown]
# ### Архитектура нейронной сети
#
# Для простоты и демонстрации принципа сжатия слоёв нейронных сетей рассмотрим архитектуру, состоящую только из полносвязных слоёв (то есть линейных преобразований) и стандартных ReLU-нелинейностей. Опять же для наглядности выбрали размерность 1000 для полносвязных слоёв.

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(3 * 32 * 32, 1000)
        self.fc2 = nn.Linear(1000, 1000)
        self.fc3 = nn.Linear(1000, 1000)
        self.fc4 = nn.Linear(1000, 1000)
        self.fc5 = nn.Linear(1000, 1000)
        self.fc6 = nn.Linear(1000, 10)
        self.ReLU = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x.view(-1, 3 * 32*32))
        x = self.ReLU(x)
        x = self.fc2(x)
        x = self.ReLU(x)
        x = self.fc3(x)
        x = self.ReLU(x)
        x = self.fc4(x)
        x = self.ReLU(x)
        x = self.fc5(x)
        x = self.ReLU(x)
        x = self.fc6(x)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# #### Функции для обучения и тестирования результата после каждого прохождения всех данных

# %%
def train(model, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %%
def test(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
#             data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return 100. * correct / len(test_loader.dataset)

# %% [markdown]
# ### Зададим параметры обучения и вывода промежуточных результатов

# %%
log_interval = 50
epochs = 7

# %% [markdown]
# ### Запускаем обучение с помощью метода оптимизации [Adam](https://arxiv.org/pdf/1412.6980.pdf%20%22%20entire%20document)
# Если у вас не очень мощный ноутбук, то придётся подождать некоторое время.

# %%
model = Net()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

for epoch in range(1, epochs + 1):
    train(model,  train_loader, optimizer, epoch)
    test(model, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.299439
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 1.906975
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 1.905558
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 1.784782
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 1.725199
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 1.723055
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 1.660464
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 1.676045
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 1.806015
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 1.618179
#
# Test set: Average loss: 1.5642, Accuracy: 4576/10000 (46%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.498605
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 1.672338
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 1.540856
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 1.359739
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 1.390302
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 1.360175
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 1.412111
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 1.463743
# Train Epoch: 2 [40000/50000 (80%)]	Loss: 1.268724
# Train Epoch: 2 [45000/50000 (90%)]	Loss: 1.588601
#
# Test set: Average loss: 1.4611, Accuracy: 4828/10000 (48%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.448895
# Train Epoch: 3 [5000/50000 (10%)]	Loss: 1.188643
# Train Epoch: 3 [10000/50000 (20%)]	Loss: 1.335541
# Train Epoch: 3 [15000/50000 (30%)]	Loss: 1.403899
# Train Epoch: 3 [20000/50000 (40%)]	Loss: 1.220070
# Train Epoch: 3 [25000/50000 (50%)]	Loss: 1.387395
# Train Epoch: 3 [30000/50000 (60%)]	Loss: 1.258315
# Train Epoch: 3 [35000/50000 (70%)]	Loss: 1.515975
# Train Epoch: 3 [40000/50000 (80%)]	Loss: 1.186940
# Train Epoch: 3 [45000/50000 (90%)]	Loss: 1.562163
#
# Test set: Average loss: 1.4613, Accuracy: 4943/10000 (49%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.136353
# Train Epoch: 4 [5000/50000 (10%)]	Loss: 1.045479
# Train Epoch: 4 [10000/50000 (20%)]	Loss: 1.191257
# Train Epoch: 4 [15000/50000 (30%)]	Loss: 1.219637
# Train Epoch: 4 [20000/50000 (40%)]	Loss: 1.115856
# Train Epoch: 4 [25000/50000 (50%)]	Loss: 1.232200
# Train Epoch: 4 [30000/50000 (60%)]	Loss: 1.310455
# Train Epoch: 4 [35000/50000 (70%)]	Loss: 1.142559
# Train Epoch: 4 [40000/50000 (80%)]	Loss: 1.185951
# Train Epoch: 4 [45000/50000 (90%)]	Loss: 1.174204
#
# Test set: Average loss: 1.3856, Accuracy: 5203/10000 (52%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.154796
# Train Epoch: 5 [5000/50000 (10%)]	Loss: 1.097905
# Train Epoch: 5 [10000/50000 (20%)]	Loss: 1.138358
# Train Epoch: 5 [15000/50000 (30%)]	Loss: 1.204378
# Train Epoch: 5 [20000/50000 (40%)]	Loss: 1.030886
# Train Epoch: 5 [25000/50000 (50%)]	Loss: 1.116895
# Train Epoch: 5 [30000/50000 (60%)]	Loss: 1.176429
# Train Epoch: 5 [35000/50000 (70%)]	Loss: 0.943988
# Train Epoch: 5 [40000/50000 (80%)]	Loss: 1.254570
# Train Epoch: 5 [45000/50000 (90%)]	Loss: 1.082513
#
# Test set: Average loss: 1.3403, Accuracy: 5372/10000 (54%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.136558
# Train Epoch: 6 [5000/50000 (10%)]	Loss: 1.093788
# Train Epoch: 6 [10000/50000 (20%)]	Loss: 1.277249
# Train Epoch: 6 [15000/50000 (30%)]	Loss: 1.254844
# Train Epoch: 6 [20000/50000 (40%)]	Loss: 1.403260
# Train Epoch: 6 [25000/50000 (50%)]	Loss: 1.208351
# Train Epoch: 6 [30000/50000 (60%)]	Loss: 1.133454
# Train Epoch: 6 [35000/50000 (70%)]	Loss: 1.042648
# Train Epoch: 6 [40000/50000 (80%)]	Loss: 0.881782
# Train Epoch: 6 [45000/50000 (90%)]	Loss: 1.153407
#
# Test set: Average loss: 1.3649, Accuracy: 5375/10000 (54%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.942478
# Train Epoch: 7 [5000/50000 (10%)]	Loss: 0.902768
# Train Epoch: 7 [10000/50000 (20%)]	Loss: 0.918149
# Train Epoch: 7 [15000/50000 (30%)]	Loss: 1.118737
# Train Epoch: 7 [20000/50000 (40%)]	Loss: 1.085660
# Train Epoch: 7 [25000/50000 (50%)]	Loss: 1.090990
# Train Epoch: 7 [30000/50000 (60%)]	Loss: 1.024723
# Train Epoch: 7 [35000/50000 (70%)]	Loss: 0.952660
# Train Epoch: 7 [40000/50000 (80%)]	Loss: 1.152359
# Train Epoch: 7 [45000/50000 (90%)]	Loss: 0.955070
#
# Test set: Average loss: 1.3429, Accuracy: 5504/10000 (55%)

# %% [markdown]
# - (3 pts) Вычислите SVD для матрицы $1000 \times 1000$, которая соответствует любому слою подходящего размера обученной нейросети. Покажите на графике убывание сингулярных чисел. Какой вывод можно сделать?

# %%
layer = model.fc3.weight.data

# %%
layer.shape
# Out:
# torch.Size([1000, 1000])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc("text", usetex=True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("talk")

layer_np = layer.numpy()
u, s, v = np.linalg.svd(layer_np)
r = s.shape[0]

plt.semilogy(s[:r]/s[0])
plt.ylabel(r"$\sigma_i / \sigma_0$", fontsize=24)
plt.xlabel(r"Singular value index, $i$", fontsize=24)
plt.show()

# %% [markdown]
# **Вывод:** Функция убывания сингулярных чисел слоя сети очень похожа на функцию убыванию гауссовой случайной матрицы, поэтому это не малоранговая матрица.

# %% [markdown]
# - (12 pts) Создайте модель (аналогично классу ```Net```), которая на вход будет принимать экземпляр класса ```Net``` и ранг $r > 0$. Эта модель должна сжимать все полносвязные слои с помощью SVD разложения, из которого берутся только первые $r$ компонент. Также функция ```forward``` должна быть эффективно реализована с использованием сжатого представления полносвязных слоёв, а в остальном полностью повторять эту же функцию для несжатой обученной сети.

# %%
from torch.nn.parameter import Parameter
class NetSVD(nn.Module):
    def __init__(self, model, r):
        super(NetSVD, self).__init__()
        fcs = [model.fc1, model.fc2, model.fc3, model.fc4, model.fc5, model.fc6]
        self.n_layers = len(fcs)
        self.U = [[]] * self.n_layers
        self.S = [[]] * self.n_layers
        self.V = [[]] * self.n_layers
        self.bias = [[]] * self.n_layers
        for i, fci in enumerate(fcs):
            u, s, v = torch.svd(fci.weight.data)
            self.U[i] = Parameter(u[:, :r])
            self.register_parameter('U' + str(i), self.U[i])
            self.S[i] = Parameter(s[:r])
            self.register_parameter('S' + str(i), self.S[i])
            self.V[i] = Parameter(v[:, :r])
            self.register_parameter('V' + str(i), self.V[i])
            self.bias[i] = Parameter(fci.bias)
        self.ReLU = nn.ReLU()
        self.ReLU = nn.ReLU()

    def forward(self, x):
        x = x.view(-1, 3 * 32*32)
        for i in range(self.n_layers):
            x = torch.mm(torch.mm(x, self.V[i]), (self.U[i] * self.S[i][None, :]).t())
            x += self.bias[i]
            x = self.ReLU(x)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# - (5 pts) Постройте зависимость точности предсказания на тестовой выборе от количества параметров, которое необходимо для этого. Это количество, очевидно, некоторым образом зависит от заданного ранга сжатия $r$. Также постройте зависимость времени вычисления от ранга сжатия. Объясните полученные результаты. Для вычисления времени используйте [%timeit](https://docs.python.org/3.6/library/timeit.html) c необходимыми параметрами (примеры смотрите в лекции)

# %%
r_range = [20*i for i in range(2, 51, 2)]
time_range = []
accuracy_range = []
for r in r_range:
    print(r)
    SVD_model = NetSVD(model, r)
    accuracy = test(SVD_model, test_loader)
    t = %timeit -o -q test(SVD_model, test_loader)
    time_range.append(t.average)
    accuracy_range.append(accuracy)
# Out:
# 40
#
# Test set: Average loss: 1.5217, Accuracy: 5147/10000 (51%)
#
#
# Test set: Average loss: 1.5217, Accuracy: 5147/10000 (51%)
#
#
# Test set: Average loss: 1.5217, Accuracy: 5147/10000 (51%)
#
#
# Test set: Average loss: 1.5217, Accuracy: 5147/10000 (51%)
#
#
# Test set: Average loss: 1.5217, Accuracy: 5147/10000 (51%)
#
#
# Test set: Average loss: 1.5217, Accuracy: 5147/10000 (51%)
#
#
# Test set: Average loss: 1.5217, Accuracy: 5147/10000 (51%)
#
#
# Test set: Average loss: 1.5217, Accuracy: 5147/10000 (51%)
#
#
# Test set: Average loss: 1.5217, Accuracy: 5147/10000 (51%)
#
# 80
#
# Test set: Average loss: 1.4083, Accuracy: 5417/10000 (54%)
#
#
# Test set: Average loss: 1.4083, Accuracy: 5417/10000 (54%)
#
#
# Test set: Average loss: 1.4083, Accuracy: 5417/10000 (54%)
#
#
# Test set: Average loss: 1.4083, Accuracy: 5417/10000 (54%)
#
#
# Test set: Average loss: 1.4083, Accuracy: 5417/10000 (54%)
#
#
# Test set: Average loss: 1.4083, Accuracy: 5417/10000 (54%)
#
#
# Test set: Average loss: 1.4083, Accuracy: 5417/10000 (54%)
#
#
# Test set: Average loss: 1.4083, Accuracy: 5417/10000 (54%)
#
#
# Test set: Average loss: 1.4083, Accuracy: 5417/10000 (54%)
#
# 120
#
# Test set: Average loss: 1.3980, Accuracy: 5442/10000 (54%)
#
#
# Test set: Average loss: 1.3980, Accuracy: 5442/10000 (54%)
#
#
# Test set: Average loss: 1.3980, Accuracy: 5442/10000 (54%)
#
#
# Test set: Average loss: 1.3980, Accuracy: 5442/10000 (54%)
#
#
# Test set: Average loss: 1.3980, Accuracy: 5442/10000 (54%)
#
#
# Test set: Average loss: 1.3980, Accuracy: 5442/10000 (54%)
#
#
# Test set: Average loss: 1.3980, Accuracy: 5442/10000 (54%)
#
#
# Test set: Average loss: 1.3980, Accuracy: 5442/10000 (54%)
#
#
# Test set: Average loss: 1.3980, Accuracy: 5442/10000 (54%)
#
# 160
#
# Test set: Average loss: 1.3943, Accuracy: 5467/10000 (55%)
#
#
# Test set: Average loss: 1.3943, Accuracy: 5467/10000 (55%)
#
#
# Test set: Average loss: 1.3943, Accuracy: 5467/10000 (55%)
#
#
# Test set: Average loss: 1.3943, Accuracy: 5467/10000 (55%)
#
#
# Test set: Average loss: 1.3943, Accuracy: 5467/10000 (55%)
#
#
# Test set: Average loss: 1.3943, Accuracy: 5467/10000 (55%)
#
#
# Test set: Average loss: 1.3943, Accuracy: 5467/10000 (55%)
#
#
# Test set: Average loss: 1.3943, Accuracy: 5467/10000 (55%)
#
#
# Test set: Average loss: 1.3943, Accuracy: 5467/10000 (55%)
#
# 200
#
# Test set: Average loss: 1.3916, Accuracy: 5473/10000 (55%)
#
#
# Test set: Average loss: 1.3916, Accuracy: 5473/10000 (55%)
#
#
# Test set: Average loss: 1.3916, Accuracy: 5473/10000 (55%)
#
#
# Test set: Average loss: 1.3916, Accuracy: 5473/10000 (55%)
#
#
# Test set: Average loss: 1.3916, Accuracy: 5473/10000 (55%)
#
#
# Test set: Average loss: 1.3916, Accuracy: 5473/10000 (55%)
#
#
# Test set: Average loss: 1.3916, Accuracy: 5473/10000 (55%)
#
#
# Test set: Average loss: 1.3916, Accuracy: 5473/10000 (55%)
#
#
# Test set: Average loss: 1.3916, Accuracy: 5473/10000 (55%)
#
# 240
#
# Test set: Average loss: 1.3880, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5485/10000 (55%)
#
# 280
#
# Test set: Average loss: 1.3891, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3891, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3891, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3891, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3891, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3891, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3891, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3891, Accuracy: 5485/10000 (55%)
#
#
# Test set: Average loss: 1.3891, Accuracy: 5485/10000 (55%)
#
# 320
#
# Test set: Average loss: 1.3880, Accuracy: 5492/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5492/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5492/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5492/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5492/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5492/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5492/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5492/10000 (55%)
#
#
# Test set: Average loss: 1.3880, Accuracy: 5492/10000 (55%)
#
# 360
#
# Test set: Average loss: 1.3872, Accuracy: 5486/10000 (55%)
#
#
# Test set: Average loss: 1.3872, Accuracy: 5486/10000 (55%)
#
#
# Test set: Average loss: 1.3872, Accuracy: 5486/10000 (55%)
#
#
# Test set: Average loss: 1.3872, Accuracy: 5486/10000 (55%)
#
#
# Test set: Average loss: 1.3872, Accuracy: 5486/10000 (55%)
#
#
# Test set: Average loss: 1.3872, Accuracy: 5486/10000 (55%)
#
#
# Test set: Average loss: 1.3872, Accuracy: 5486/10000 (55%)
#
#
# Test set: Average loss: 1.3872, Accuracy: 5486/10000 (55%)
#
#
# Test set: Average loss: 1.3872, Accuracy: 5486/10000 (55%)
#
# 400
#
# Test set: Average loss: 1.3863, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3863, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3863, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3863, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3863, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3863, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3863, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3863, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3863, Accuracy: 5504/10000 (55%)
#
# 440
#
# Test set: Average loss: 1.3855, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3855, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3855, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3855, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3855, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3855, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3855, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3855, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3855, Accuracy: 5484/10000 (55%)
#
# 480
#
# Test set: Average loss: 1.3854, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3854, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3854, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3854, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3854, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3854, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3854, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3854, Accuracy: 5484/10000 (55%)
#
#
# Test set: Average loss: 1.3854, Accuracy: 5484/10000 (55%)
#
# 520
#
# Test set: Average loss: 1.3856, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5500/10000 (55%)
#
# 560
#
# Test set: Average loss: 1.3856, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5501/10000 (55%)
#
# 600
#
# Test set: Average loss: 1.3858, Accuracy: 5495/10000 (55%)
#
#
# Test set: Average loss: 1.3858, Accuracy: 5495/10000 (55%)
#
#
# Test set: Average loss: 1.3858, Accuracy: 5495/10000 (55%)
#
#
# Test set: Average loss: 1.3858, Accuracy: 5495/10000 (55%)
#
#
# Test set: Average loss: 1.3858, Accuracy: 5495/10000 (55%)
#
#
# Test set: Average loss: 1.3858, Accuracy: 5495/10000 (55%)
#
#
# Test set: Average loss: 1.3858, Accuracy: 5495/10000 (55%)
#
#
# Test set: Average loss: 1.3858, Accuracy: 5495/10000 (55%)
# Test set: Average loss: 1.3858, Accuracy: 5495/10000 (55%)
#
# 640
#
# Test set: Average loss: 1.3860, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3860, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3860, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3860, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3860, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3860, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3860, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3860, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3860, Accuracy: 5501/10000 (55%)
#
# 680
#
# Test set: Average loss: 1.3856, Accuracy: 5499/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5499/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5499/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5499/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5499/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5499/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5499/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5499/10000 (55%)
#
#
# Test set: Average loss: 1.3856, Accuracy: 5499/10000 (55%)
#
# 720
#
# Test set: Average loss: 1.3857, Accuracy: 5495/10000 (55%)
#
#
# Test set: Average loss: 1.3857, Accuracy: 5495/10000 (55%)
#
#
# Test set: Average loss: 1.3857, Accuracy: 5495/10000 (55%)
#
#
# Test set: Average loss: 1.3857, Accuracy: 5495/10000 (55%)
#
#
# Test set: Average loss: 1.3857, Accuracy: 5495/10000 (55%)
#
#
# Test set: Average loss: 1.3857, Accuracy: 5495/10000 (55%)
#
#
# Test set: Average loss: 1.3857, Accuracy: 5495/10000 (55%)
#
#
# Test set: Average loss: 1.3857, Accuracy: 5495/10000 (55%)
#
#
# Test set: Average loss: 1.3857, Accuracy: 5495/10000 (55%)
#
# 760
#
# Test set: Average loss: 1.3853, Accuracy: 5498/10000 (55%)
#
#
# Test set: Average loss: 1.3853, Accuracy: 5498/10000 (55%)
#
#
# Test set: Average loss: 1.3853, Accuracy: 5498/10000 (55%)
#
#
# Test set: Average loss: 1.3853, Accuracy: 5498/10000 (55%)
#
#
# Test set: Average loss: 1.3853, Accuracy: 5498/10000 (55%)
#
#
# Test set: Average loss: 1.3853, Accuracy: 5498/10000 (55%)
#
#
# Test set: Average loss: 1.3853, Accuracy: 5498/10000 (55%)
#
#
# Test set: Average loss: 1.3853, Accuracy: 5498/10000 (55%)
#
#
# Test set: Average loss: 1.3853, Accuracy: 5498/10000 (55%)
#
# 800
#
# Test set: Average loss: 1.3851, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3851, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3851, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3851, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3851, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3851, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3851, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3851, Accuracy: 5501/10000 (55%)
#
#
# Test set: Average loss: 1.3851, Accuracy: 5501/10000 (55%)
#
# 840
#
# Test set: Average loss: 1.3850, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3850, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3850, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3850, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3850, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3850, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3850, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3850, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3850, Accuracy: 5500/10000 (55%)
#
# 880
#
# Test set: Average loss: 1.3849, Accuracy: 5506/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5506/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5506/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5506/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5506/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5506/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5506/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5506/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5506/10000 (55%)
#
# 920
#
# Test set: Average loss: 1.3849, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5500/10000 (55%)
#
#
# Test set: Average loss: 1.3849, Accuracy: 5500/10000 (55%)
#
# 960
#
# Test set: Average loss: 1.3848, Accuracy: 5502/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5502/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5502/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5502/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5502/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5502/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5502/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5502/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5502/10000 (55%)
#
# 1000
#
# Test set: Average loss: 1.3848, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5504/10000 (55%)
#
#
# Test set: Average loss: 1.3848, Accuracy: 5504/10000 (55%)

# %%
plt.plot(r_range, time_range)
plt.legend(fontsize=18)
plt.xlabel("r", fontsize=18)
plt.ylabel("time, seconds", fontsize=18)
# Out:
# No handles with labels found to put in legend.
# Text(0, 0.5, 'time, seconds')

# %%
plt.plot(r_range, accuracy_range)
plt.legend(fontsize=18)
plt.xlabel("r", fontsize=18)
plt.ylabel("accuracy, %", fontsize=18)
# Out:
# No handles with labels found to put in legend.
# Text(0, 0.5, 'accuracy, %')

# %%
print(r_range[np.argmax(accuracy_range)], max(accuracy_range))
# Out:
# 880 55.06

# %% [markdown]
# Лучшая точность достигается на $r=880$ (не ухудшается по сравнению с исходной моделью). Это значит, что все матрицы весов нашей модели примерно ранга 880 - мы не добавили лишней информации и не удалили необходимую. Время на оценивание закономерно растёт с размерностью усечённого SVD, так как операций в умножении матриц становится больше.

# %% [markdown]
# ### Fine-tuning
#
# - (10 pts) Поскольку в вашей модели, которая использует сжатое представление линейных слоёв, параметрами являются матрицы, полученные из SVD соответствующих линейных слоёв, то их также можно оптимизировать. Эта процедура называется fine-tuning. Предлагается провести обучение этих матриц в течение нескольких эпох (от 1 до 5 будет достаточно) и сравнить насколько выросло качество по сравнению с первоначальными значениями. Покажите значения точности на тестовой выборки и объясните полученные результаты.

# %%
epochs_SVD = 4
SVD_model = NetSVD(model, r_range[np.argmax(accuracy_range)])
for epoch in range(1, epochs_SVD + 1):
    train(SVD_model,  train_loader, optimizer, epoch)
    test(SVD_model, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 1.208788
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 0.909228
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 1.006024
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 0.987619
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 0.861735
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 1.041914
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 1.082336
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 0.969720
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 0.974673
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 1.001817
#
# Test set: Average loss: 1.3845, Accuracy: 5507/10000 (55%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.034506
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 1.027727
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 0.921793
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 1.050494
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 1.076238
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 1.058729
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 0.855147
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 0.975995
# Train Epoch: 2 [40000/50000 (80%)]	Loss: 0.918588
# Train Epoch: 2 [45000/50000 (90%)]	Loss: 0.897441
#
# Test set: Average loss: 1.3845, Accuracy: 5507/10000 (55%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.133196
# Train Epoch: 3 [5000/50000 (10%)]	Loss: 1.071845
# Train Epoch: 3 [10000/50000 (20%)]	Loss: 0.877663
# Train Epoch: 3 [15000/50000 (30%)]	Loss: 0.899247
# Train Epoch: 3 [20000/50000 (40%)]	Loss: 1.196197
# Train Epoch: 3 [25000/50000 (50%)]	Loss: 0.888920
# Train Epoch: 3 [30000/50000 (60%)]	Loss: 0.980173
# Train Epoch: 3 [35000/50000 (70%)]	Loss: 0.951835
# Train Epoch: 3 [40000/50000 (80%)]	Loss: 1.085996
# Train Epoch: 3 [45000/50000 (90%)]	Loss: 1.062276
#
# Test set: Average loss: 1.3845, Accuracy: 5507/10000 (55%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.028822
# Train Epoch: 4 [5000/50000 (10%)]	Loss: 0.966314
# Train Epoch: 4 [10000/50000 (20%)]	Loss: 1.054964
# Train Epoch: 4 [15000/50000 (30%)]	Loss: 1.195400
# Train Epoch: 4 [20000/50000 (40%)]	Loss: 1.138199
# Train Epoch: 4 [25000/50000 (50%)]	Loss: 1.058384
# Train Epoch: 4 [30000/50000 (60%)]	Loss: 0.885491
# Train Epoch: 4 [35000/50000 (70%)]	Loss: 0.883171
# Train Epoch: 4 [40000/50000 (80%)]	Loss: 1.061723
# Train Epoch: 4 [45000/50000 (90%)]	Loss: 1.013578
#
# Test set: Average loss: 1.3845, Accuracy: 5507/10000 (55%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.895360
# Train Epoch: 5 [5000/50000 (10%)]	Loss: 1.151069
# Train Epoch: 5 [10000/50000 (20%)]	Loss: 0.975084
# Train Epoch: 5 [15000/50000 (30%)]	Loss: 0.994414
# Train Epoch: 5 [20000/50000 (40%)]	Loss: 1.145203
# Train Epoch: 5 [25000/50000 (50%)]	Loss: 0.989799
# Train Epoch: 5 [30000/50000 (60%)]	Loss: 1.150704
# Train Epoch: 5 [35000/50000 (70%)]	Loss: 1.051438
# Train Epoch: 5 [40000/50000 (80%)]	Loss: 0.918986
# Train Epoch: 5 [45000/50000 (90%)]	Loss: 0.889596
#
# Test set: Average loss: 1.3845, Accuracy: 5507/10000 (55%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.865005
# Train Epoch: 6 [5000/50000 (10%)]	Loss: 1.034531
# Train Epoch: 6 [10000/50000 (20%)]	Loss: 1.001813
# Train Epoch: 6 [15000/50000 (30%)]	Loss: 1.103980
# Train Epoch: 6 [20000/50000 (40%)]	Loss: 1.098411
# Train Epoch: 6 [25000/50000 (50%)]	Loss: 1.009003
# Train Epoch: 6 [30000/50000 (60%)]	Loss: 0.998604
# Train Epoch: 6 [35000/50000 (70%)]	Loss: 0.986592
# Train Epoch: 6 [40000/50000 (80%)]	Loss: 1.079890
# Train Epoch: 6 [45000/50000 (90%)]	Loss: 0.984773
#
# Test set: Average loss: 1.3845, Accuracy: 5507/10000 (55%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.028248
# Train Epoch: 7 [5000/50000 (10%)]	Loss: 1.018584
# Train Epoch: 7 [10000/50000 (20%)]	Loss: 1.054464
# Train Epoch: 7 [15000/50000 (30%)]	Loss: 1.104831
# Train Epoch: 7 [20000/50000 (40%)]	Loss: 0.983675
# Train Epoch: 7 [25000/50000 (50%)]	Loss: 0.929357
# Train Epoch: 7 [30000/50000 (60%)]	Loss: 1.061277
# Train Epoch: 7 [35000/50000 (70%)]	Loss: 1.047733
# Train Epoch: 7 [40000/50000 (80%)]	Loss: 1.020299
# Train Epoch: 7 [45000/50000 (90%)]	Loss: 0.966718
#
# Test set: Average loss: 1.3845, Accuracy: 5507/10000 (55%)

# %% [markdown]
# Я случайно посчитал 7 эпох :( accuracy стала лучше на 0.01 процента. Сильного выигрыша эта процедура не может дать, потому что никакой дополнительной информации ни о выборке, ни о модели мы не получаем.
